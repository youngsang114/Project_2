# %%
import pandas as pd

# %%
df=pd.read_excel('./kosdaq_dp.xls')

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', 'Unnamed: 13',
#        'Unnamed: 14'],
#       dtype='object')

# %%
df[['2022']].value_counts()
# Out:
# 2022
# 4                  485
# 3                  288
# 6                  249
# 5                  219
# 8                  131
# 2                   75
# 7                   75
# 9                   49
# 10                  19
# KIS 신용평점/0A3010      1
# dtype: int64

# %%
회사명=df['Unnamed: 2'].to_list()
회사명
# Out:
# ['Name',
#  '(주)메타바이오메드',
#  '(주)이건홀딩스',
#  '(주)대성미생물연구소',
#  '(주)휴온스글로벌',
#  '(주)이글벳',
#  '대화제약(주)',
#  '한라아이엠에스(주)',
#  '한스바이오메드(주)',
#  '(주)제이브이엠',
#  '(주)팬스타엔터프라이즈',
#  '(주)대창솔루션',
#  '(주)에스티큐브',
#  '(주)인지디스플레이',
#  '(주)아즈텍더블유비이',
#  '바이온(주)',
#  '(주)웰크론',
#  '조광아이엘아이(주)',
#  '(주)무궁화인포메이션테크놀로지',
#  '(주)상아프론테크',
#  '(주)서울리거',
#  '(주)대한과학',
#  '(주)코맥스',
#  '(주)포메탈',
#  '(주)미래컴퍼니',
#  '삼지전자(주)',
#  '신화인터텍(주)',
#  '(주)파워넷',
#  '제이엠아이(주)',
#  '동아화성(주)',
#  '(주)에쎈테크',
#  '(주)코엔텍',
#  '(주)한국팩키지',
#  '티제이미디어(주)',
#  '(주)와이티엔',
#  '국일신동(주)',
#  '(주)뉴프렉스',
#  '(주)동우팜투테이블',
#  '(주)한국파마',
#  '(주)형지아이앤씨',
#  '(주)나노엔텍',
#  '(주)비씨월드제약',
#  '(주)현대에버다임',
#  '신흥에스이씨(주)',
#  '(주)룽투코리아',
#  '(주)판타지오',
#  '(주)국보디자인',
#  '(주)국순당',
#  '케이엔솔(주)',
#  '성우전자(주)',
#  '(주)드래곤플라이',
#  '(주)ES큐브',
#  '(주)듀오백',
#  '대보마그네틱(주)',
#  '(주)녹원씨엔아이',
#  '(주)케이피엠테크',
#  '대한뉴팜(주)',
#  '(주)에이치알에스',
#  '유아이엘(주)',
#  '우수AMS(주)',
#  '(주)바이넥스',
#  '(주)아이에이',
#  '(주)이랜텍',
#  '(주)코미팜',
#  '(주)에이텍',
#  '(주)이스트소프트',
# ...

# %%
len(회사명)
# Out:
# 1662

# %%
외감=pd.read_excel('./외감_dp.xls')
외감
# Out:
#       Unnamed: 0 Unnamed: 1     Unnamed: 2             2013             2014  \
# 0            KIS      Stock           Name  KIS 신용평점/0A3010  KIS 신용평점/0A3010
# 1         000083        NaN        청우화학(주)                3                3
# 2         000292     059210     (주)메타바이오메드                5                7
# 3         000356        NaN       코디아산업(주)                5                6
# 4         000366        NaN          (주)코라                3                6
# ...          ...        ...            ...              ...              ...
# 37025     V10366        NaN      (주)우전지앤에프               10                7
# 37026     X01379        NaN        다마요팩(주)                6                5
# 37027     X57312        NaN        (주)에스엘씨                8                7
# 37028     X91216        NaN  농업회사법인한국양계(주)                6                6
# 37029     Y32604        NaN  (주)메디라인액티브코리아                7                7
#
# ...

# %%
외감[['2022']].value_counts()
# Out:
# 2022
# 4                  8056
# 6                  6564
# 5                  6072
# 8                  4589
# 3                  4398
# 7                  1838
# 9                  1808
# 2                   966
# 10                  529
# 1                     4
# KIS 신용평점/0A3010       1
# dtype: int64

# %%
외감[외감['2022']==1]
# Out:
#       Unnamed: 0 Unnamed: 1        Unnamed: 2 2013 2014 2015 2016 2017 2018  \
# 5465      165202        NaN  (주)태원종합기술단건축사사무소    3    3    3    3    4    3
# 9698      321699     009970        (주)영원무역홀딩스    4    2    2    2    2    2
# 9959      350079     003550             (주)LG    2    2    2    2    2    2
# 16264     826278        NaN         (주)귀뚜라미랜드    2    2    2    2    2    2
#
#       2019 2020 2021 2022 Unnamed: 13 Unnamed: 14
# 5465     2    3    2    1         NaN         NaN
# 9698     2    2    2    1         NaN          A+
# 9959     3    2    1    1          A1         NaN
# 16264    2    2    2    1         NaN         NaN
