# %%
import pandas as pd

# %%
df1=pd.read_csv('./Dataset/개별/개별_1.csv',encoding='euc-kr')
df2=pd.read_csv('./Dataset/개별/개별_2.csv',encoding='euc-kr')
df3=pd.read_csv('./Dataset/개별/개별_3.csv',encoding='euc-kr')
df4=pd.read_csv('./Dataset/개별/개별_4.csv',encoding='euc-kr')
df5=pd.read_csv('./Dataset/개별/개별_5.csv',encoding='euc-kr')
df6=pd.read_csv('./Dataset/개별/개별_6.csv',encoding='euc-kr')
df7=pd.read_csv('./Dataset/개별/개별_7.csv',encoding='euc-kr')
df8=pd.read_csv('./Dataset/개별/개별_8.csv',encoding='euc-kr')
df9=pd.read_csv('./Dataset/개별/개별_9.csv',encoding='euc-kr')
df10=pd.read_csv('./Dataset/개별/개별_10.csv',encoding='euc-kr')
df11=pd.read_csv('./Dataset/개별/개별_11.csv',encoding='euc-kr')
df12=pd.read_csv('./Dataset/개별/개별_12.csv',encoding='euc-kr')
df13=pd.read_csv('./Dataset/개별/개별_13.csv',encoding='euc-kr')
df14=pd.read_csv('./Dataset/개별/개별_14.csv',encoding='euc-kr')

# %%
df_외감개별=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14],axis=0)
df_외감연결=pd.read_csv('./외감기업(IFRS연결).csv',encoding='euc-kr')
df_외감가프=pd.read_csv('./외감기업(GAAP).csv',encoding='euc-kr',index_col=0)

# %%
# df.to_csv('외감기업(IFRS개별).csv',index=False,encoding='euc-kr')

# %%
df11.head(5)
# Out:
#            회사명   거래소코드     회계년도  통계청 한국표준산업분류 코드 10차(대분류)    부채비율     당좌비율
# 0    (유)주영산업개발   93799  2019/12                        41   31.79  1187.82  \
# 1    (유)주영산업개발   93799  2020/12                        41   25.83   685.14
# 2    (유)주영산업개발   93799  2021/12                        41   13.01   442.32
# 3    (유)주영산업개발   93799  2022/12                        41    5.85  1029.36
# 4  (유)중산MOTORS  105441  2021/12                        45  594.61    38.38
#
#       유동비율  이자보상배율(이자비용)  영업활동으로 인한 현금흐름(간접법)(*)(IFRS)(천원)  이자비용(IFRS)(천원)
# 0  2341.71         -5.55                               NaN             NaN  \
# 1  1067.87       3763.72                               NaN             NaN
# 2   947.72         58.09                               NaN             NaN
# 3  2540.68         -7.47                               NaN             NaN
# 4    61.70          1.90                               NaN             NaN
#
#    ...  노동소득분배율  자본분배율   이윤분배율  투자활동으로 인한 현금흐름(*)(IFRS)(천원)
# ...

# %%
df_외감개별['* (정상)영업손익(보고서기재)(IFRS)(천원)'].isna().sum()
# Out:
# 271086

# %%
df_외감가프['연구비'] +=df_외감가프['경상개발비(요약)(백만원)']
df_외감가프.drop('경상개발비(요약)(백만원)',axis=1,inplace=True)

# %%
df_외감가프
# Out:
#              회사명  거래소코드     회계년도  통계청 한국표준산업분류 코드 10차(대분류)    부채비율      당좌비율
# 0        (유)가든주류  97082  2019/12                        46  178.34    213.01  \
# 1        (유)가든주류  97082  2020/12                        46  361.81    115.89
# 2        (유)가든주류  97082  2021/12                        46  281.83    176.11
# 3        (유)가든주류  97082  2022/12                        46    0.00     28.33
# 4     (유)그룹세브코리아  13171  2019/12                        46  147.02     92.20
# ...          ...    ...      ...                       ...     ...       ...
# 3455   힐티코리아주식회사  10534  2021/12                        46   83.55    116.00
# 3456   힐티코리아주식회사  10534  2022/12                        46  108.21     95.88
# 3457   （주）신미코스메틱  85105  2017/12                        46   31.40    416.15
# 3458   （주）신미코스메틱  85105  2018/12                        46   15.51    677.00
# 3459   （주）신미코스메틱  85105  2019/12                        46    0.88  13972.49
#
# ...

# %%
df2.shape
# Out:
# (24610, 50)
