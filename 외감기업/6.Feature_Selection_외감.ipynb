# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %%
train = pd.read_csv('../data/train.csv', encoding='euc-kr')
test = pd.read_csv('../data/test.csv', encoding='euc-kr')

# %%
train['자산총계(천원)'] = train['자산총계(천원)'] * 1000
train['log자산총계'] = np.log(train['자산총계(천원)'])

test['자산총계(천원)'] = test['자산총계(천원)'] * 1000
test['log자산총계'] = np.log(test['자산총계(천원)'])

# %%
train['기업수명주기'] = train['기업수명주기'].map({
    '도입기' : 1,
    '성장기' : 2,
    '성숙기' : 3,
    '수축기' : 4,
    '쇠퇴기' : 5
}).astype('category')

test['기업수명주기'] = test['기업수명주기'].map({
    '도입기' : 1,
    '성장기' : 2,
    '성숙기' : 3,
    '수축기' : 4,
    '쇠퇴기' : 5
}).astype('category')

# %% [markdown]
# # Filter Method
# ## t-test & chi-square

# %% [markdown]
# - t-test 하기 위해 연속형 컬럼만 추출

# %%
train.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', 'Year', '산업분류코드', '산업분류', '부채비율', '당좌비율',
#        '유동비율', '이자보상배율', 'OCF(천원)', '이자비용(천원)', '차입금의존도', '자기자본구성비율',
#        '당기순이익(천원)', '감가상각비(백만원)', '금융비용(백만원)', '단기차입금(천원)', '유동성장기부채(천원)',
#        '장기차입금(천원)', '법인세비용차감전손익(백만원)', '매출액영업이익률', '자기자본순이익률', '총자본순이익률',
#        '매출액(천원)', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률', '재고자산회전률',
#        '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율', '순이익증가율',
#        '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율', '부가가치율',
#        '노동소득분배율', '자본분배율', '이윤분배율', 'ICF(천원)', 'FCF(천원)', '자산총계(천원)',
#        '부채총계(천원)', '자본총계(천원)', '자본금(천원)', '영업손익(천원)', '연구개발비(천원)', '자본잠식률',
#        'OCF이자보상배율', '부채상환계수', '장기부채상환능력', '매출액대비금융비용상환능력', '전체현금흐름(천원)',
#        '잉여현금흐름(FCF)', '연구개발비대비매출액', '매출액대비현금흐름', '매출액대비잉여현금흐름', '총자산대비현금흐름',
#        '총자산대비영업현금흐름', '총자산대비잉여현금흐름', '기업수명주기', 't-1감사의견코드', '이보배S.E', '평균이보배',
#        '이보배초과여부', '파부비S.E', '평균파부비', '파부비초과여부', '파당비S.E', '평균파당비', '파당비초과여부',
#        '파차의S.E', '평균파차의', '파차의초과여부', '파로이S.E', '평균파로이', '파로이초과여부', 'log자산총계'],
#       dtype='object')

# %%
train_int = train[['부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도', '자기자본구성비율', '매출액영업이익률',
      '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률', '재고자산회전률',
       '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율', '순이익증가율',
       '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율', '부가가치율',
       '노동소득분배율', '자본분배율', '이윤분배율', 'log자산총계',
       'OCF이자보상배율', '부채상환계수', '장기부채상환능력', '매출액대비금융비용상환능력', '연구개발비대비매출액', '매출액대비현금흐름',
       '매출액대비잉여현금흐름', '총자산대비현금흐름', '총자산대비영업현금흐름', '총자산대비잉여현금흐름',
       't-1감사의견코드']]

# %%
test_int = test[['부채비율', '당좌비율', '유동비율', '이자보상배율', '차입금의존도', '자기자본구성비율', '매출액영업이익률',
      '자기자본순이익률', '총자본순이익률', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률', '재고자산회전률',
       '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율', '순이익증가율',
       '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율', '부가가치율',
       '노동소득분배율', '자본분배율', '이윤분배율', 'log자산총계',
       'OCF이자보상배율', '부채상환계수', '장기부채상환능력', '매출액대비금융비용상환능력', '연구개발비대비매출액', '매출액대비현금흐름',
       '매출액대비잉여현금흐름', '총자산대비현금흐름', '총자산대비영업현금흐름', '총자산대비잉여현금흐름',
       't-1감사의견코드']]

# %% [markdown]
# # Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
X_train = train_int.drop('t-1감사의견코드', axis=1)
y_train = train_int[['t-1감사의견코드']]

X_test = test_int.drop('t-1감사의견코드', axis=1)
y_test = test_int[['t-1감사의견코드']]

# %%
scaler = StandardScaler()
train_sc = scaler.fit_transform(X_train)
test_sc = scaler.transform(X_test)

# %%
train_sc = pd.DataFrame(train_sc, columns=X_train.columns)
test_sc = pd.DataFrame(test_sc, columns=X_test.columns)

# %%
# 스케일링 + 타겟 데이터프레임
train_sc_total = pd.concat([train_sc, y_train], axis=1)
test_sc_total = pd.concat([test_sc, y_test], axis=1)

# %% [markdown]
# # MDA

# %%
# 1-1 정규성 테스트(샤피로)
from scipy.stats import norm
from scipy import stats
from statsmodels.formula.api import ols
from scipy.stats import kstest

for j in train_sc_total.columns:
    a = stats.shapiro(train_sc_total[j])
    p = a.pvalue
    print(j,a)
# Out:
# 부채비율 ShapiroResult(statistic=0.0005869269371032715, pvalue=0.0)
# 당좌비율 ShapiroResult(statistic=0.0011895298957824707, pvalue=0.0)
# 유동비율 ShapiroResult(statistic=0.0014246702194213867, pvalue=0.0)
# 이자보상배율 ShapiroResult(statistic=0.005773186683654785, pvalue=0.0)
# 차입금의존도 ShapiroResult(statistic=0.01571822166442871, pvalue=0.0)
# 자기자본구성비율 ShapiroResult(statistic=0.9559506177902222, pvalue=0.0)
# 매출액영업이익률 ShapiroResult(statistic=0.0007175207138061523, pvalue=0.0)
# 자기자본순이익률 ShapiroResult(statistic=0.001079261302947998, pvalue=0.0)
# 총자본순이익률 ShapiroResult(statistic=0.29977643489837646, pvalue=0.0)
# 총자본회전률 ShapiroResult(statistic=0.11430180072784424, pvalue=0.0)
# 자기자본회전률 ShapiroResult(statistic=0.0008434057235717773, pvalue=0.0)
# 운전자본회전률 ShapiroResult(statistic=0.0013790726661682129, pvalue=0.0)
# 순운전자본회전률 ShapiroResult(statistic=0.0006452798843383789, pvalue=0.0)
# 재고자산회전률 ShapiroResult(statistic=0.002703845500946045, pvalue=0.0)
# 당좌자산회전률 ShapiroResult(statistic=0.00038367509841918945, pvalue=0.0)
# 유동자산회전률 ShapiroResult(statistic=0.0003160238265991211, pvalue=0.0)
# 매출액증가율 ShapiroResult(statistic=0.00046515464782714844, pvalue=0.0)
# 총자본증가율 ShapiroResult(statistic=0.18000465631484985, pvalue=0.0)
# 자기자본증가율 ShapiroResult(statistic=0.0016636848449707031, pvalue=0.0)
# 순이익증가율 ShapiroResult(statistic=0.0014674663543701172, pvalue=0.0)
# 유형자산증가율 ShapiroResult(statistic=0.0003725290298461914, pvalue=0.0)
# 유동자산증가율 ShapiroResult(statistic=0.0006735324859619141, pvalue=0.0)
# 재고자산증가율 ShapiroResult(statistic=0.0012132525444030762, pvalue=0.0)
# 영업이익증가율 ShapiroResult(statistic=0.0007802844047546387, pvalue=0.0)
# 총자본투자효율 ShapiroResult(statistic=0.001487135887145996, pvalue=0.0)
# 부가가치율 ShapiroResult(statistic=0.001048445701599121, pvalue=0.0)
# 노동소득분배율 ShapiroResult(statistic=0.0018954277038574219, pvalue=0.0)
# 자본분배율 ShapiroResult(statistic=0.0019562244415283203, pvalue=0.0)
# 이윤분배율 ShapiroResult(statistic=0.002537071704864502, pvalue=0.0)
# log자산총계 ShapiroResult(statistic=0.9186384677886963, pvalue=0.0)
# OCF이자보상배율 ShapiroResult(statistic=0.006373047828674316, pvalue=0.0)
# 부채상환계수 ShapiroResult(statistic=0.004679262638092041, pvalue=0.0)
# 장기부채상환능력 ShapiroResult(statistic=0.0045920610427856445, pvalue=0.0)
# 매출액대비금융비용상환능력 ShapiroResult(statistic=0.007448971271514893, pvalue=0.0)
# 연구개발비대비매출액 ShapiroResult(statistic=0.0007810592651367188, pvalue=0.0)
# 매출액대비현금흐름 ShapiroResult(statistic=0.001807093620300293, pvalue=0.0)
# 매출액대비잉여현금흐름 ShapiroResult(statistic=0.0028568506240844727, pvalue=0.0)
# 총자산대비현금흐름 ShapiroResult(statistic=0.645726203918457, pvalue=0.0)
# 총자산대비영업현금흐름 ShapiroResult(statistic=0.000280916690826416, pvalue=0.0)
# 총자산대비잉여현금흐름 ShapiroResult(statistic=0.0003215670585632324, pvalue=0.0)
# t-1감사의견코드 ShapiroResult(statistic=0.27632713317871094, pvalue=0.0)

# %%
# 1-2 정규성 테스트(K-S)
for j in train_sc_total.columns:
    a = kstest(train_sc_total[j],'norm')
    p = a.pvalue
    print(j,a)
# Out:
# 부채비율 KstestResult(statistic=0.49744877473659, pvalue=0.0, statistic_location=-0.006395016968642688, statistic_sign=-1)
# 당좌비율 KstestResult(statistic=0.49583664064734667, pvalue=0.0, statistic_location=-0.010436183708679665, statistic_sign=-1)
# 유동비율 KstestResult(statistic=0.4952851388782335, pvalue=0.0, statistic_location=-0.011818679334195302, statistic_sign=-1)
# 이자보상배율 KstestResult(statistic=0.4866878680672493, pvalue=0.0, statistic_location=-0.024431627364804406, statistic_sign=-1)
# 차입금의존도 KstestResult(statistic=0.44350510903606427, pvalue=0.0, statistic_location=-0.1420883526484764, statistic_sign=-1)
# 자기자본구성비율 KstestResult(statistic=0.0758168364052138, pvalue=0.0, statistic_location=-1.4333778461001914, statistic_sign=-1)
# 매출액영업이익률 KstestResult(statistic=0.49670538243468476, pvalue=0.0, statistic_location=0.008021783663275424, statistic_sign=1)
# 자기자본순이익률 KstestResult(statistic=0.47965144849329566, pvalue=0.0, statistic_location=0.03069266934585124, statistic_sign=1)
# 총자본순이익률 KstestResult(statistic=0.25792204171260535, pvalue=0.0, statistic_location=-0.33344407952917304, statistic_sign=-1)
# 총자본회전률 KstestResult(statistic=0.39071847539697135, pvalue=0.0, statistic_location=-0.27742800878048907, statistic_sign=-1)
# 자기자본회전률 KstestResult(statistic=0.49637039428577845, pvalue=0.0, statistic_location=-0.009079990621253411, statistic_sign=-1)
# 운전자본회전률 KstestResult(statistic=0.4962569569257449, pvalue=0.0, statistic_location=-0.009382555262659343, statistic_sign=-1)
# 순운전자본회전률 KstestResult(statistic=0.4947388669568969, pvalue=0.0, statistic_location=-0.01316987908765026, statistic_sign=-1)
# 재고자산회전률 KstestResult(statistic=0.4937373711416139, pvalue=0.0, statistic_location=-0.01569872737144794, statistic_sign=-1)
# 당좌자산회전률 KstestResult(statistic=0.49727114047103393, pvalue=0.0, statistic_location=-0.0068220829152510504, statistic_sign=-1)
# 유동자산회전률 KstestResult(statistic=0.49773145316581663, pvalue=0.0, statistic_location=-0.00566822753423811, statistic_sign=-1)
# 매출액증가율 KstestResult(statistic=0.4976459936340723, pvalue=0.0, statistic_location=-0.00588244638580814, statistic_sign=-1)
# 총자본증가율 KstestResult(statistic=0.2904729924248173, pvalue=0.0, statistic_location=-0.36244822508081254, statistic_sign=-1)
# 자기자본증가율 KstestResult(statistic=0.48653622820615217, pvalue=0.0, statistic_location=-0.033736863262139836, statistic_sign=-1)
# 순이익증가율 KstestResult(statistic=0.49389025466695685, pvalue=0.0, statistic_location=-0.01442324418296374, statistic_sign=-1)
# 유형자산증가율 KstestResult(statistic=0.49824630674782805, pvalue=0.0, statistic_location=-0.004395871248287211, statistic_sign=-1)
# 유동자산증가율 KstestResult(statistic=0.4947665095144431, pvalue=0.0, statistic_location=-0.013118791512948287, statistic_sign=-1)
# 재고자산증가율 KstestResult(statistic=0.4951351598376327, pvalue=0.0, statistic_location=-0.01219464813903111, statistic_sign=-1)
# 영업이익증가율 KstestResult(statistic=0.4954591956321508, pvalue=0.0, statistic_location=-0.010726881960666554, statistic_sign=-1)
# 총자본투자효율 KstestResult(statistic=0.4854134246646398, pvalue=0.0, statistic_location=-0.02704444270505794, statistic_sign=-1)
# 부가가치율 KstestResult(statistic=0.49138666442534795, pvalue=0.0, statistic_location=0.006497325231309224, statistic_sign=1)
# 노동소득분배율 KstestResult(statistic=0.49224002383163146, pvalue=0.0, statistic_location=-0.018687792252457088, statistic_sign=-1)
# 자본분배율 KstestResult(statistic=0.49106723033852395, pvalue=0.0, statistic_location=0.021628147978079375, statistic_sign=1)
# 이윤분배율 KstestResult(statistic=0.489279172058969, pvalue=0.0, statistic_location=0.01988316185150926, statistic_sign=1)
# log자산총계 KstestResult(statistic=0.09234517231883654, pvalue=0.0, statistic_location=0.056854806112461354, statistic_sign=1)
# OCF이자보상배율 KstestResult(statistic=0.48430458754899486, pvalue=0.0, statistic_location=-0.026382629117360404, statistic_sign=-1)
# 부채상환계수 KstestResult(statistic=0.4780860320868808, pvalue=0.0, statistic_location=-0.014184601539057273, statistic_sign=-1)
# 장기부채상환능력 KstestResult(statistic=0.47193768534671177, pvalue=0.0, statistic_location=-0.024992114082769065, statistic_sign=-1)
# 매출액대비금융비용상환능력 KstestResult(statistic=0.46417157927170094, pvalue=0.0, statistic_location=0.05106918021727468, statistic_sign=1)
# 연구개발비대비매출액 KstestResult(statistic=0.4972228962317772, pvalue=0.0, statistic_location=-0.006924809261359419, statistic_sign=-1)
# 매출액대비현금흐름 KstestResult(statistic=0.4874654645849387, pvalue=0.0, statistic_location=-0.013541096141072037, statistic_sign=-1)
# 매출액대비잉여현금흐름 KstestResult(statistic=0.4887539149295109, pvalue=0.0, statistic_location=0.018723492278118755, statistic_sign=1)
# 총자산대비현금흐름 KstestResult(statistic=0.19195981573305695, pvalue=0.0, statistic_location=-0.3884531390552744, statistic_sign=-1)
# 총자산대비영업현금흐름 KstestResult(statistic=0.489126713752142, pvalue=0.0, statistic_location=0.019045326967854742, statistic_sign=1)
# 총자산대비잉여현금흐름 KstestResult(statistic=0.4879246674923474, pvalue=0.0, statistic_location=0.019946632665436573, statistic_sign=1)
# t-1감사의견코드 KstestResult(statistic=0.5, pvalue=0.0, statistic_location=0.0, statistic_sign=-1)

# %% [markdown]
# p-value가 0 이는 데이터개수가 많아서 p-value 자체가 너무작아 계산이 불가능하다고 판단. 중심극한 정리에 의해서 정규성이 있다고 가정하고 진행

# %%
# 부도기업과 정상기업의 피처별 등분산비교 (정규성 가정으로 bartlett)
Bad = train_sc_total[train_sc_total['t-1감사의견코드']== 1] #Existing Customer
Good = train_sc_total[train_sc_total['t-1감사의견코드']== 0] #Attrited Customer

c = []
for i in train_sc_total:
    # lresult = stats.levene(close[i], normal[i])
    lresult = stats.bartlett(Bad[i], Good[i])
    c.append([i,lresult[-1]])

c= pd.DataFrame(c)
c.columns=["피처값",'F-test']
c
# Out:
#               피처값         F-test
# 0            부채비율   0.000000e+00
# 1            당좌비율   0.000000e+00
# 2            유동비율   0.000000e+00
# 3          이자보상배율   0.000000e+00
# 4          차입금의존도   0.000000e+00
# 5        자기자본구성비율   1.167465e-94
# 6        매출액영업이익률   0.000000e+00
# 7        자기자본순이익률   0.000000e+00
# 8         총자본순이익률   0.000000e+00
# 9          총자본회전률   0.000000e+00
# 10        자기자본회전률   0.000000e+00
# 11        운전자본회전률   0.000000e+00
# 12       순운전자본회전률   0.000000e+00
# 13        재고자산회전률   0.000000e+00
# 14        당좌자산회전률   0.000000e+00
# 15        유동자산회전률   0.000000e+00
# 16         매출액증가율   0.000000e+00
# 17         총자본증가율   0.000000e+00
# 18        자기자본증가율   0.000000e+00
# 19         순이익증가율   0.000000e+00
# 20        유형자산증가율   0.000000e+00
# 21        유동자산증가율   0.000000e+00
# 22        재고자산증가율   0.000000e+00
# 23        영업이익증가율   0.000000e+00
# 24        총자본투자효율   0.000000e+00
# 25          부가가치율   0.000000e+00
# 26        노동소득분배율   0.000000e+00
# 27          자본분배율   0.000000e+00
# 28          이윤분배율   7.539636e-24
# 29        log자산총계   0.000000e+00
# 30      OCF이자보상배율   0.000000e+00
# 31         부채상환계수  5.048259e-187
# 32       장기부채상환능력   0.000000e+00
# 33  매출액대비금융비용상환능력   0.000000e+00
# 34     연구개발비대비매출액   0.000000e+00
# 35      매출액대비현금흐름   0.000000e+00
# 36    매출액대비잉여현금흐름   0.000000e+00
# 37      총자산대비현금흐름   8.289357e-78
# 38    총자산대비영업현금흐름   0.000000e+00
# 39    총자산대비잉여현금흐름   0.000000e+00
# 40      t-1감사의견코드            NaN

# %%
# F-test 결과 0.05 이상이면 homo 0.05 이하이면 hetero
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
    else:
        c.loc[i,"분산"] = "hetero"
c
# Out:
#               피처값         F-test      분산 T-test
# 0            부채비율   0.000000e+00  hetero
# 1            당좌비율   0.000000e+00  hetero
# 2            유동비율   0.000000e+00  hetero
# 3          이자보상배율   0.000000e+00  hetero
# 4          차입금의존도   0.000000e+00  hetero
# 5        자기자본구성비율   1.167465e-94  hetero
# 6        매출액영업이익률   0.000000e+00  hetero
# 7        자기자본순이익률   0.000000e+00  hetero
# 8         총자본순이익률   0.000000e+00  hetero
# 9          총자본회전률   0.000000e+00  hetero
# 10        자기자본회전률   0.000000e+00  hetero
# 11        운전자본회전률   0.000000e+00  hetero
# 12       순운전자본회전률   0.000000e+00  hetero
# 13        재고자산회전률   0.000000e+00  hetero
# 14        당좌자산회전률   0.000000e+00  hetero
# 15        유동자산회전률   0.000000e+00  hetero
# 16         매출액증가율   0.000000e+00  hetero
# 17         총자본증가율   0.000000e+00  hetero
# 18        자기자본증가율   0.000000e+00  hetero
# 19         순이익증가율   0.000000e+00  hetero
# 20        유형자산증가율   0.000000e+00  hetero
# 21        유동자산증가율   0.000000e+00  hetero
# 22        재고자산증가율   0.000000e+00  hetero
# 23        영업이익증가율   0.000000e+00  hetero
# 24        총자본투자효율   0.000000e+00  hetero
# 25          부가가치율   0.000000e+00  hetero
# 26        노동소득분배율   0.000000e+00  hetero
# 27          자본분배율   0.000000e+00  hetero
# 28          이윤분배율   7.539636e-24  hetero
# 29        log자산총계   0.000000e+00  hetero
# 30      OCF이자보상배율   0.000000e+00  hetero
# 31         부채상환계수  5.048259e-187  hetero
# 32       장기부채상환능력   0.000000e+00  hetero
# 33  매출액대비금융비용상환능력   0.000000e+00  hetero
# 34     연구개발비대비매출액   0.000000e+00  hetero
# 35      매출액대비현금흐름   0.000000e+00  hetero
# 36    매출액대비잉여현금흐름   0.000000e+00  hetero
# 37      총자산대비현금흐름   8.289357e-78  hetero
# 38    총자산대비영업현금흐름   0.000000e+00  hetero
# 39    총자산대비잉여현금흐름   0.000000e+00  hetero
# 40      t-1감사의견코드            NaN  hetero

# %%
c[c["분산"]=='homo']
# Out:
# Empty DataFrame
# Columns: [피처값, F-test, 분산, T-test]
# Index: []

# %%
c
# Out:
#               피처값         F-test      분산 T-test
# 0            부채비율   0.000000e+00  hetero
# 1            당좌비율   0.000000e+00  hetero
# 2            유동비율   0.000000e+00  hetero
# 3          이자보상배율   0.000000e+00  hetero
# 4          차입금의존도   0.000000e+00  hetero
# 5        자기자본구성비율   1.167465e-94  hetero
# 6        매출액영업이익률   0.000000e+00  hetero
# 7        자기자본순이익률   0.000000e+00  hetero
# 8         총자본순이익률   0.000000e+00  hetero
# 9          총자본회전률   0.000000e+00  hetero
# 10        자기자본회전률   0.000000e+00  hetero
# 11        운전자본회전률   0.000000e+00  hetero
# 12       순운전자본회전률   0.000000e+00  hetero
# 13        재고자산회전률   0.000000e+00  hetero
# 14        당좌자산회전률   0.000000e+00  hetero
# 15        유동자산회전률   0.000000e+00  hetero
# 16         매출액증가율   0.000000e+00  hetero
# 17         총자본증가율   0.000000e+00  hetero
# 18        자기자본증가율   0.000000e+00  hetero
# 19         순이익증가율   0.000000e+00  hetero
# 20        유형자산증가율   0.000000e+00  hetero
# 21        유동자산증가율   0.000000e+00  hetero
# 22        재고자산증가율   0.000000e+00  hetero
# 23        영업이익증가율   0.000000e+00  hetero
# 24        총자본투자효율   0.000000e+00  hetero
# 25          부가가치율   0.000000e+00  hetero
# 26        노동소득분배율   0.000000e+00  hetero
# 27          자본분배율   0.000000e+00  hetero
# 28          이윤분배율   7.539636e-24  hetero
# 29        log자산총계   0.000000e+00  hetero
# 30      OCF이자보상배율   0.000000e+00  hetero
# 31         부채상환계수  5.048259e-187  hetero
# 32       장기부채상환능력   0.000000e+00  hetero
# 33  매출액대비금융비용상환능력   0.000000e+00  hetero
# 34     연구개발비대비매출액   0.000000e+00  hetero
# 35      매출액대비현금흐름   0.000000e+00  hetero
# 36    매출액대비잉여현금흐름   0.000000e+00  hetero
# 37      총자산대비현금흐름   8.289357e-78  hetero
# 38    총자산대비영업현금흐름   0.000000e+00  hetero
# 39    총자산대비잉여현금흐름   0.000000e+00  hetero
# 40      t-1감사의견코드            NaN  hetero

# %%
# homo 인 feature 는 student t-test, hetero이면 Welchs T-Test 진행
c["분산"] =''
c["T-test"] =""
for i in c.index:
    if c.loc[i,"F-test"]>=0.05:
        c.loc[i,"분산"] = "homo"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=True)       ## equal_var = True Student T-test
        c.loc[i,"T-test"] = result[-1]
        print(Bad[c.loc[i,"피처값"]])
    else:
        c.loc[i,"분산"] = "hetero"
        result = stats.ttest_ind(Bad[c.loc[i,"피처값"]], Good[c.loc[i,"피처값"]], equal_var=False)      ## equal_var = False Welchs T-Test
        c.loc[i,"T-test"] = result[-1]
c
# Out:
#               피처값         F-test      분산    T-test
# 0            부채비율   0.000000e+00  hetero   0.53001
# 1            당좌비율   0.000000e+00  hetero  0.008492
# 2            유동비율   0.000000e+00  hetero  0.006085
# 3          이자보상배율   0.000000e+00  hetero  0.169462
# 4          차입금의존도   0.000000e+00  hetero   0.02846
# 5        자기자본구성비율   1.167465e-94  hetero       0.0
# 6        매출액영업이익률   0.000000e+00  hetero  0.050517
# 7        자기자본순이익률   0.000000e+00  hetero  0.724641
# 8         총자본순이익률   0.000000e+00  hetero  0.000864
# 9          총자본회전률   0.000000e+00  hetero       0.0
# 10        자기자본회전률   0.000000e+00  hetero  0.027422
# 11        운전자본회전률   0.000000e+00  hetero  0.215569
# 12       순운전자본회전률   0.000000e+00  hetero  0.002208
# 13        재고자산회전률   0.000000e+00  hetero  0.000138
# 14        당좌자산회전률   0.000000e+00  hetero  0.679084
# 15        유동자산회전률   0.000000e+00  hetero   0.59304
# 16         매출액증가율   0.000000e+00  hetero  0.113505
# 17         총자본증가율   0.000000e+00  hetero       0.0
# 18        자기자본증가율   0.000000e+00  hetero  0.055713
# 19         순이익증가율   0.000000e+00  hetero  0.000637
# 20        유형자산증가율   0.000000e+00  hetero  0.104998
# 21        유동자산증가율   0.000000e+00  hetero  0.363067
# 22        재고자산증가율   0.000000e+00  hetero  0.218847
# 23        영업이익증가율   0.000000e+00  hetero  0.013501
# 24        총자본투자효율   0.000000e+00  hetero  0.241575
# 25          부가가치율   0.000000e+00  hetero  0.375324
# 26        노동소득분배율   0.000000e+00  hetero  0.384679
# 27          자본분배율   0.000000e+00  hetero  0.379901
# 28          이윤분배율   7.539636e-24  hetero  0.408166
# 29        log자산총계   0.000000e+00  hetero       0.0
# 30      OCF이자보상배율   0.000000e+00  hetero  0.010711
# 31         부채상환계수  5.048259e-187  hetero  0.402529
# 32       장기부채상환능력   0.000000e+00  hetero  0.033151
# 33  매출액대비금융비용상환능력   0.000000e+00  hetero  0.012374
# 34     연구개발비대비매출액   0.000000e+00  hetero  0.153766
# 35      매출액대비현금흐름   0.000000e+00  hetero  0.889668
# 36    매출액대비잉여현금흐름   0.000000e+00  hetero  0.108452
# 37      총자산대비현금흐름   8.289357e-78  hetero       0.0
# 38    총자산대비영업현금흐름   0.000000e+00  hetero  0.326967
# 39    총자산대비잉여현금흐름   0.000000e+00  hetero  0.362409
# 40      t-1감사의견코드            NaN  hetero       0.0

# %%
# 0.05 이상이면 유의미하지 않으므로 0.05 이하인 것만 추출
d = c[c["T-test"]<= 0.05]
d.sort_values('T-test',ascending=False)["피처값"].unique()
# d.sort_values('T-test',ascending=False)["피처값"]
# Out:
# array(['장기부채상환능력', '차입금의존도', '자기자본회전률', '영업이익증가율', '매출액대비금융비용상환능력',
#        'OCF이자보상배율', '당좌비율', '유동비율', '순운전자본회전률', '총자본순이익률', '순이익증가율',
#        '재고자산회전률', '총자산대비현금흐름', '총자본회전률', '총자본증가율', 'log자산총계', '자기자본구성비율',
#        't-1감사의견코드'], dtype=object)

# %%
d.sort_values('T-test',ascending=False).dropna()
# Out:
#               피처값        F-test      분산    T-test
# 32       장기부채상환능력  0.000000e+00  hetero  0.033151
# 4          차입금의존도  0.000000e+00  hetero   0.02846
# 10        자기자본회전률  0.000000e+00  hetero  0.027422
# 23        영업이익증가율  0.000000e+00  hetero  0.013501
# 33  매출액대비금융비용상환능력  0.000000e+00  hetero  0.012374
# 30      OCF이자보상배율  0.000000e+00  hetero  0.010711
# 1            당좌비율  0.000000e+00  hetero  0.008492
# 2            유동비율  0.000000e+00  hetero  0.006085
# 12       순운전자본회전률  0.000000e+00  hetero  0.002208
# 8         총자본순이익률  0.000000e+00  hetero  0.000864
# 19         순이익증가율  0.000000e+00  hetero  0.000637
# 13        재고자산회전률  0.000000e+00  hetero  0.000138
# 37      총자산대비현금흐름  8.289357e-78  hetero       0.0
# 9          총자본회전률  0.000000e+00  hetero       0.0
# 17         총자본증가율  0.000000e+00  hetero       0.0
# 29        log자산총계  0.000000e+00  hetero       0.0
# 5        자기자본구성비율  1.167465e-94  hetero       0.0

# %%
d['피처값'].values
# Out:
# array(['당좌비율', '유동비율', '차입금의존도', '자기자본구성비율', '총자본순이익률', '총자본회전률',
#        '자기자본회전률', '순운전자본회전률', '재고자산회전률', '총자본증가율', '순이익증가율', '영업이익증가율',
#        'log자산총계', 'OCF이자보상배율', '장기부채상환능력', '매출액대비금융비용상환능력', '총자산대비현금흐름',
#        't-1감사의견코드'], dtype=object)

# %%
# t-test가 가장 작은순으로 의미 있으므로 가장작은 순위로 12개 피처 선정
fea = ['당좌비율', '유동비율', '차입금의존도', '자기자본구성비율', '총자본순이익률', '총자본회전률',
       '자기자본회전률', '순운전자본회전률', '재고자산회전률', '총자본증가율', '순이익증가율', '영업이익증가율',
       'log자산총계', 'OCF이자보상배율', '장기부채상환능력', '매출액대비금융비용상환능력', '총자산대비현금흐름'
       ]
mda_feature = train[fea]
mda_feature
# Out:
#           당좌비율    유동비율  차입금의존도  자기자본구성비율  총자본순이익률  총자본회전률  자기자본회전률  순운전자본회전률  \
# 0       347.96  354.61    6.09      7.40   -90.18    0.17     2.28      0.14
# 1        68.72   68.72   45.96     48.26     6.61    0.36     0.76      0.81
# 2       109.86  109.86    0.00     20.04    -1.80    0.10     0.68      0.06
# 3        55.31   55.31   70.59     27.22    18.17    0.40     1.48      2.09
# 4        30.73  124.85    1.76     20.41    27.88    1.17    17.19      0.69
# ...        ...     ...     ...       ...      ...     ...      ...       ...
# 137673   84.46  129.25   19.60     19.98    10.04    2.20    14.88      1.33
# 137674  148.14  158.66   25.22     42.55     3.32    3.04     8.55      2.13
# 137675  223.79  300.12   18.78     66.65    36.01    2.00     3.27      1.99
# 137676  272.56  280.21    7.13     78.62     1.43    0.88     1.15      1.09
# 137677    7.74    7.74   32.75      3.13     1.61    0.28    11.72      0.53
#
#         재고자산회전률  총자본증가율   순이익증가율  영업이익증가율    log자산총계   OCF이자보상배율  장기부채상환능력  \
# 0          9.53    0.00     0.00     0.00  22.828067   -9.332108 -0.000000
# 1          0.00   -0.04   -19.83    -6.98  23.977288    9.548280  2.352094
# 2          0.00  -49.82     0.00     0.00  23.592060 -618.027372 -0.000000
# 3          0.00    0.00     0.00     0.00  23.265147    5.010647  4.843848
# 4          1.47    3.50     0.00     0.00  23.488822   16.602420  0.000000
# ...         ...     ...      ...      ...        ...         ...       ...
# 137673     6.91   -1.60    22.36    19.39  23.805059    4.818200  0.000000
# 137674    36.81  -21.61   -62.60   -26.36  25.560289    4.835895  0.036460
# 137675    10.11   52.23     0.00     0.00  22.865585   40.753692  0.163392
# 137676    33.58   -3.79  2238.26     0.00  24.057147   40.446933  0.295099
# 137677     0.00    2.62   -68.86   -22.51  24.213767    4.299987  0.696463
#
#         매출액대비금융비용상환능력  총자산대비현금흐름
# 0            4.174742   0.772454
# 1           56.802819   0.000884
# 2          -23.752940  -0.516536
# 3           26.994572  -0.149208
# 4           46.704264  -0.001722
# ...               ...        ...
# 137673     213.217431  -0.003247
# 137674     195.625970  -0.018967
# 137675     288.357414   0.215584
# 137676    -288.743530   0.063097
# 137677      32.488890  -0.000420
#
# [137678 rows x 17 columns]

# %%
def vif(data):
    import pandas as pd
    from statsmodels.stats.outliers_influence import variance_inflation_factor

    # VIF 출력을 위한 데이터 프레임 형성
    vif = pd.DataFrame()

    # VIF 값과 각 Feature 이름에 대해 설정
    vif["VIF Factor"] = [variance_inflation_factor(data.values, i) for i in range(len(data.columns))]
    vif["features"] = data.columns 
                    
    # VIF 값이 높은 순으로 정렬
    vif = vif.sort_values(by="VIF Factor", ascending=False)
    vif = vif.reset_index().drop(columns='index')
    
    return vif

vif(mda_feature)
# Out:
#     VIF Factor       features
# 0    45.310796           당좌비율
# 1    45.150614           유동비율
# 2     3.307882        log자산총계
# 3     3.245975       자기자본구성비율
# 4     1.176584       장기부채상환능력
# 5     1.087598         총자본회전률
# 6     1.062461        총자본순이익률
# 7     1.033903         총자본증가율
# 8     1.030056      총자산대비현금흐름
# 9     1.028777         차입금의존도
# 10    1.012653        자기자본회전률
# 11    1.009847       순운전자본회전률
# 12    1.008575  매출액대비금융비용상환능력
# 13    1.001173      OCF이자보상배율
# 14    1.000362        재고자산회전률
# 15    1.000171        영업이익증가율
# 16    1.000163         순이익증가율

# %%
# t-test가 가장 작은순으로 의미 있으므로 가장작은 순위로 12개 피처 선정
fea = ['당좌비율', '차입금의존도', '자기자본구성비율', '총자본순이익률', '총자본회전률',
       '자기자본회전률', '순운전자본회전률', '재고자산회전률', '총자본증가율', '순이익증가율', '영업이익증가율',
       'log자산총계', 'OCF이자보상배율', '장기부채상환능력', '매출액대비금융비용상환능력', '총자산대비현금흐름'
       ]
mda_feature2 = train[fea]
mda_feature2
# Out:
#           당좌비율  차입금의존도  자기자본구성비율  총자본순이익률  총자본회전률  자기자본회전률  순운전자본회전률  재고자산회전률  \
# 0       347.96    6.09      7.40   -90.18    0.17     2.28      0.14     9.53
# 1        68.72   45.96     48.26     6.61    0.36     0.76      0.81     0.00
# 2       109.86    0.00     20.04    -1.80    0.10     0.68      0.06     0.00
# 3        55.31   70.59     27.22    18.17    0.40     1.48      2.09     0.00
# 4        30.73    1.76     20.41    27.88    1.17    17.19      0.69     1.47
# ...        ...     ...       ...      ...     ...      ...       ...      ...
# 137673   84.46   19.60     19.98    10.04    2.20    14.88      1.33     6.91
# 137674  148.14   25.22     42.55     3.32    3.04     8.55      2.13    36.81
# 137675  223.79   18.78     66.65    36.01    2.00     3.27      1.99    10.11
# 137676  272.56    7.13     78.62     1.43    0.88     1.15      1.09    33.58
# 137677    7.74   32.75      3.13     1.61    0.28    11.72      0.53     0.00
#
#         총자본증가율   순이익증가율  영업이익증가율    log자산총계   OCF이자보상배율  장기부채상환능력  \
# 0         0.00     0.00     0.00  22.828067   -9.332108 -0.000000
# 1        -0.04   -19.83    -6.98  23.977288    9.548280  2.352094
# 2       -49.82     0.00     0.00  23.592060 -618.027372 -0.000000
# 3         0.00     0.00     0.00  23.265147    5.010647  4.843848
# 4         3.50     0.00     0.00  23.488822   16.602420  0.000000
# ...        ...      ...      ...        ...         ...       ...
# 137673   -1.60    22.36    19.39  23.805059    4.818200  0.000000
# 137674  -21.61   -62.60   -26.36  25.560289    4.835895  0.036460
# 137675   52.23     0.00     0.00  22.865585   40.753692  0.163392
# 137676   -3.79  2238.26     0.00  24.057147   40.446933  0.295099
# 137677    2.62   -68.86   -22.51  24.213767    4.299987  0.696463
#
#         매출액대비금융비용상환능력  총자산대비현금흐름
# 0            4.174742   0.772454
# 1           56.802819   0.000884
# 2          -23.752940  -0.516536
# 3           26.994572  -0.149208
# 4           46.704264  -0.001722
# ...               ...        ...
# 137673     213.217431  -0.003247
# 137674     195.625970  -0.018967
# 137675     288.357414   0.215584
# 137676    -288.743530   0.063097
# 137677      32.488890  -0.000420
#
# [137678 rows x 16 columns]

# %%
vif(mda_feature2)
# Out:
#     VIF Factor       features
# 0     3.307603        log자산총계
# 1     3.245920       자기자본구성비율
# 2     1.176578       장기부채상환능력
# 3     1.173595           당좌비율
# 4     1.087595         총자본회전률
# 5     1.062461        총자본순이익률
# 6     1.033902         총자본증가율
# 7     1.030047      총자산대비현금흐름
# 8     1.028777         차입금의존도
# 9     1.012653        자기자본회전률
# 10    1.009847       순운전자본회전률
# 11    1.008575  매출액대비금융비용상환능력
# 12    1.001173      OCF이자보상배율
# 13    1.000362        재고자산회전률
# 14    1.000171        영업이익증가율
# 15    1.000163         순이익증가율

# %%
# Welch's t-test 수행
t_stat, p_value = stats.ttest_ind(Bad[fea], Good[fea], equal_var=False)

# 결과를 데이터프레임으로 변환
result_df = pd.DataFrame({'t-statistic': t_stat, 'p-value': p_value}, index=fea)

result_df = result_df.sort_values('p-value', ascending=True).reset_index()

# %%
result_df = result_df[['index', 'p-value']]
result_df.columns = ['Variable', 'p-value']

# %%
result_df
# Out:
#   Variable       p-value
# 0   기업수명주기  0.000000e+00
# 1  이보배초과여부  1.290877e-01
# 2  파부비초과여부  0.000000e+00
# 3  파당비초과여부  3.922972e-04
# 4  파차의초과여부  0.000000e+00
# 5  파로이초과여부  1.909617e-59

# %% [markdown]
# ---

# %% [markdown]
# # Chi 2

# %% [markdown]
# * 카이제곱 검정 조건
#     * 종속변인은 범주형 자료여야 한다.
#     * 기대빈도가 5이하인 셀이 전체의 20%가 넘지 않아야 한다.
#     * 각 칸의 빈도는 다른 칸의 빈도와 독립적이어야 한다.

# %% [markdown]
# - 범주형 변수만 추출

# %%
train.columns
# Out:
# Index(['회사명', '거래소코드', '회계년도', 'Year', '산업분류코드', '산업분류', '부채비율', '당좌비율',
#        '유동비율', '이자보상배율', 'OCF(천원)', '이자비용(천원)', '차입금의존도', '자기자본구성비율',
#        '당기순이익(천원)', '감가상각비(백만원)', '금융비용(백만원)', '단기차입금(천원)', '유동성장기부채(천원)',
#        '장기차입금(천원)', '법인세비용차감전손익(백만원)', '매출액영업이익률', '자기자본순이익률', '총자본순이익률',
#        '매출액(천원)', '총자본회전률', '자기자본회전률', '운전자본회전률', '순운전자본회전률', '재고자산회전률',
#        '당좌자산회전률', '유동자산회전률', '매출액증가율', '총자본증가율', '자기자본증가율', '순이익증가율',
#        '유형자산증가율', '유동자산증가율', '재고자산증가율', '영업이익증가율', '총자본투자효율', '부가가치율',
#        '노동소득분배율', '자본분배율', '이윤분배율', 'ICF(천원)', 'FCF(천원)', '자산총계(천원)',
#        '부채총계(천원)', '자본총계(천원)', '자본금(천원)', '영업손익(천원)', '연구개발비(천원)', '자본잠식률',
#        'OCF이자보상배율', '부채상환계수', '장기부채상환능력', '매출액대비금융비용상환능력', '전체현금흐름(천원)',
#        '잉여현금흐름(FCF)', '연구개발비대비매출액', '매출액대비현금흐름', '매출액대비잉여현금흐름', '총자산대비현금흐름',
#        '총자산대비영업현금흐름', '총자산대비잉여현금흐름', '기업수명주기', 't-1감사의견코드', '이보배S.E', '평균이보배',
#        '이보배초과여부', '파부비S.E', '평균파부비', '파부비초과여부', '파당비S.E', '평균파당비', '파당비초과여부',
#        '파차의S.E', '평균파차의', '파차의초과여부', '파로이S.E', '평균파로이', '파로이초과여부', 'log자산총계'],
#       dtype='object')

# %%
train_cat = train[['기업수명주기', 't-1감사의견코드', '이보배초과여부', '파부비초과여부', '파당비초과여부', '파차의초과여부', '파로이초과여부']].astype('category')
test_cat = test[['기업수명주기', 't-1감사의견코드', '이보배초과여부', '파부비초과여부', '파당비초과여부', '파차의초과여부', '파로이초과여부']].astype('category')

# %%
X_train_cat = train_cat.drop('t-1감사의견코드', axis=1)
y_train_cat = train['t-1감사의견코드']
X_test_cat = test_cat.drop('t-1감사의견코드', axis=1)
y_test_cat = test['t-1감사의견코드']

# %%
from scipy.stats import chi2_contingency

# 기대빈도가 5 이하인 항목의 비율을 저장할 딕셔너리
expected_freq_5_ratio = {}

# 각 독립 변수에 대해 기대빈도 계산 및 비율 확인
for column in train_cat.columns[:-1]:
    # 교차 테이블 생성
    contingency_table = pd.crosstab(train_cat[column], train_cat['t-1감사의견코드'])
    
    # 카이제곱 검정 수행
    chi2, p_value, dof, expected_freq = chi2_contingency(contingency_table)
    
    # 기대빈도가 5 이하인 항목의 비율 계산
    expected_freq_5 = (expected_freq <= 5).mean()
    
    # 결과 저장
    expected_freq_5_ratio[column] = expected_freq_5

# 결과 출력
for column, ratio in expected_freq_5_ratio.items():
    print(f"변수 '{column}'의 기대빈도가 5 이하인 항목 비율: {ratio}")
# Out:
# 변수 '기업수명주기'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 't-1감사의견코드'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 '이보배초과여부'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 '파부비초과여부'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 '파당비초과여부'의 기대빈도가 5 이하인 항목 비율: 0.0
# 변수 '파차의초과여부'의 기대빈도가 5 이하인 항목 비율: 0.0

# %%
# 독립변수와 종속변수 간의 카이제곱 검정 수행
chi2_scores = []

for column in X_train_cat.columns:
    # 교차 테이블 생성
    contingency_table = pd.crosstab(X_train_cat[column], y_train_cat)
    chi2, p_value, dof, expected_freq = chi2_contingency(contingency_table)
    # 카이제곱 통계량(chi2), p-value(p_value), 자유도(dof), 예상빈도(expected_freq)
    print(p_value)
    chi2_scores.append((column, chi2))

# 카이제곱 검정 결과를 기준으로 변수 정렬
sorted_features = sorted(chi2_scores, key=lambda x : x[1], reverse=True)

# 선택된 변수 출력
sorted_features
# Out:
# 0.0
# 0.12908771021386392
# 0.0
# 0.00039229715645192347
# 0.0
# 1.9096172238484248e-59
# [('기업수명주기', 3089.2507048662806),
#  ('파차의초과여부', 1985.8292770838254),
#  ('파부비초과여부', 1906.060822214597),
#  ('파로이초과여부', 264.3747900999849),
#  ('파당비초과여부', 12.568529415290646),
#  ('이보배초과여부', 2.303441378969885)]

# %%
chi2_scores
# Out:
# [('기업수명주기', 3089.2507048662806),
#  ('이보배초과여부', 2.303441378969885),
#  ('파부비초과여부', 1906.060822214597),
#  ('파당비초과여부', 12.568529415290646),
#  ('파차의초과여부', 1985.8292770838254),
#  ('파로이초과여부', 264.3747900999849)]

# %%
import pandas as pd
from scipy.stats import chi2_contingency

# 독립변수와 종속변수 간의 카이제곱 검정 수행
chi2_scores = []

p_values = []
for column in X_train_cat.columns:
    # 교차 테이블 생성
    contingency_table = pd.crosstab(X_train_cat[column], y_train_cat)
    chi2, p_value, dof, expected_freq = chi2_contingency(contingency_table)
    p_values.append(p_value)
    chi2_scores.append((column, chi2))

# p-value가 0.05보다 작은 값을 출력하는 데이터프레임 생성
result_df = pd.DataFrame({'Variable': X_train_cat.columns, 'p-value': p_values})
filtered_df_chi = result_df[result_df['p-value'] < 0.05]

filtered_df_chi
# Out:
#   Variable       p-value
# 0   기업수명주기  0.000000e+00
# 2  파부비초과여부  0.000000e+00
# 3  파당비초과여부  3.922972e-04
# 4  파차의초과여부  0.000000e+00
# 5  파로이초과여부  1.909617e-59

# %%
result_df
# Out:
#          Variable       p-value
# 0        자기자본구성비율  0.000000e+00
# 1         log자산총계  0.000000e+00
# 2          총자본증가율  4.006026e-74
# 3          총자본회전률  8.385602e-36
# 4       총자산대비현금흐름  6.909689e-34
# 5         재고자산회전률  1.384389e-04
# 6          순이익증가율  6.370057e-04
# 7         총자본순이익률  8.639113e-04
# 8        순운전자본회전률  2.207923e-03
# 9            당좌비율  8.492177e-03
# 10      OCF이자보상배율  1.071066e-02
# 11  매출액대비금융비용상환능력  1.237392e-02
# 12        영업이익증가율  1.350113e-02
# 13        자기자본회전률  2.742223e-02
# 14         차입금의존도  2.846012e-02
# 15       장기부채상환능력  3.315100e-02

# %%
result = pd.concat([result_df, filtered_df_chi], axis=0)

# %%
result
# Out:
#          Variable       p-value
# 0        자기자본구성비율  0.000000e+00
# 1         log자산총계  0.000000e+00
# 2          총자본증가율  4.006026e-74
# 3          총자본회전률  8.385602e-36
# 4       총자산대비현금흐름  6.909689e-34
# 5         재고자산회전률  1.384389e-04
# 6          순이익증가율  6.370057e-04
# 7         총자본순이익률  8.639113e-04
# 8        순운전자본회전률  2.207923e-03
# 9            당좌비율  8.492177e-03
# 10      OCF이자보상배율  1.071066e-02
# 11  매출액대비금융비용상환능력  1.237392e-02
# 12        영업이익증가율  1.350113e-02
# 13        자기자본회전률  2.742223e-02
# 14         차입금의존도  2.846012e-02
# 15       장기부채상환능력  3.315100e-02
# 0          기업수명주기  0.000000e+00
# 2         파부비초과여부  0.000000e+00
# 3         파당비초과여부  3.922972e-04
# 4         파차의초과여부  0.000000e+00
# 5         파로이초과여부  1.909617e-59

# %%
result.sort_values('p-value', ascending=True).reset_index(drop=True)
# Out:
#          Variable       p-value
# 0        자기자본구성비율  0.000000e+00
# 1         log자산총계  0.000000e+00
# 2         파부비초과여부  0.000000e+00
# 3          기업수명주기  0.000000e+00
# 4         파차의초과여부  0.000000e+00
# 5          총자본증가율  4.006026e-74
# 6         파로이초과여부  1.909617e-59
# 7          총자본회전률  8.385602e-36
# 8       총자산대비현금흐름  6.909689e-34
# 9         재고자산회전률  1.384389e-04
# 10        파당비초과여부  3.922972e-04
# 11         순이익증가율  6.370057e-04
# 12        총자본순이익률  8.639113e-04
# 13       순운전자본회전률  2.207923e-03
# 14           당좌비율  8.492177e-03
# 15      OCF이자보상배율  1.071066e-02
# 16  매출액대비금융비용상환능력  1.237392e-02
# 17        영업이익증가율  1.350113e-02
# 18        자기자본회전률  2.742223e-02
# 19         차입금의존도  2.846012e-02
# 20       장기부채상환능력  3.315100e-02

# %% [markdown]
# ---

# %%
# 스케일링된 연속형 변수와 범주형 변수 합치기
logit_ = pd.concat([train_sc_total, X_train_cat], axis=1)
X_logit = logit_.drop('t-1감사의견코드', axis=1)
y_logit = logit_[['t-1감사의견코드']]

# %% [markdown]
# #### Feature 개수 정하기 위해 Logit

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
import statsmodels.api as sm
import numpy as np
lr_clf = LogisticRegression()

feature = X_logit
target = y_logit

logit = SelectFromModel(LogisticRegression())
logit.fit(feature, target)
logit_support = logit.get_support()
lr_feature = feature.loc[:,logit_support].columns.tolist()

# %%
lr_feature
# Out:
# ['매출액영업이익률',
#  '재고자산회전률',
#  '당좌자산회전률',
#  '유동자산회전률',
#  '총자본증가율',
#  '순이익증가율',
#  '유형자산증가율',
#  '영업이익증가율',
#  '총자본투자효율',
#  'log자산총계',
#  '총자산대비영업현금흐름',
#  '총자산대비잉여현금흐름',
#  '파당비초과여부']

# %% [markdown]
# 자기자본구성비율	0.000000e+00
# 1	log자산총계	0.000000e+00
# 2	파부비초과여부	0.000000e+00
# 3	기업수명주기	0.000000e+00
# 4	파차의초과여부	0.000000e+00
# 5	총자본증가율	4.006026e-74
# 6	파로이초과여부	1.909617e-59
# 7	총자본회전률	8.385602e-36
# 8	총자산대비현금흐름	6.909689e-34
# 9	재고자산회전률	1.384389e-04
# 10	파당비초과여부	3.922972e-04
# 11	순이익증가율	6.370057e-04
# 12	총자본순이익률	8.639113e-04
# 13	순운전자본회전률	2.207923e-03
# 14	당좌비율	8.492177e-03
# 15	OCF이자보상배율	1.071066e-02
# 16	매출액대비금융비용상환능력	1.237392e-02
# 17	영업이익증가율	1.350113e-02
# 18	자기자본회전률	2.742223e-02
# 19	차입금의존도	2.846012e-02
# 20	장기부채상환능력	3.315100e-02

# %% [markdown]
# ---

# %% [markdown]
# ### Embedded Method

# %% [markdown]
# > Randomforeset

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
selector = SelectFromModel(estimator=RandomForestClassifier(), threshold=0.021).fit(X_logit, y_logit)
rf = selector.get_support()
count = np.count_nonzero(rf)
count
# Out:
# 22

# %%
rf_features = X_logit.loc[:, rf].columns.tolist()
rf_features

# %% [markdown]
# > LASSO

# %%
lasso = SelectFromModel(estimator=LogisticRegression(penalty='l1', solver='liblinear', C=0.0115)).fit(X_logit, y_logit)
lasso_support = lasso.get_support()
lasso_feature = X_logit.loc[:,lasso_support].columns.tolist()

# %%
len(lasso_feature)
# Out:
# 13

# %%
lasso_feature
# Out:
# ['자기자본구성비율',
#  '총자본순이익률',
#  '총자본회전률',
#  '자기자본회전률',
#  '총자본증가율',
#  '유동자산증가율',
#  'log자산총계',
#  '부채상환계수',
#  '장기부채상환능력',
#  '총자산대비현금흐름',
#  '기업수명주기',
#  '파부비초과여부',
#  '파차의초과여부']
